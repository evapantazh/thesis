# %%
import sys
import os

# This will print the path to your venv to confirm you are inside it
print(f"Current Python Path: {sys.executable}")

try:
    import pyk4a
    import mediapipe
    print("✅ All libraries found in this venv!")
except ImportError as e:
    print(f"❌ Missing library: {e}")
    print("Tip: Run 'pip install pyk4a mediapipe opencv-python' in the terminal")
